# %% [markdown]
# # 5주차: 원자의 구조

# %% [markdown]
# ## 1. 원자구조1 - 고전적 모델

# %% [markdown]
# ### 원자번호 Z인 원자의 경우
# - 원자핵 : $Z_e$
# - 전자 : $-e$
# - 원자핵의 지름 = $10^{-15} m$
# - 원자핵과 전자간의 거리 = 약 $ 1 \mathring A $ ($10^{-10} m$)
# - 원자핵과 전자간의 거리는 쿨롱법칙을 따름
#
# #### 원자핵과 전자간의 힘
# $ F(r) = k_e \frac{q_1 q_2}{r^2} = k_e \frac{Z e^2}{r^2} = \frac{Z e^2}{4 \pi \epsilon_0 r^2} $ ($ k_e = \frac{1}{4 \pi \epsilon_0} $)
# #### 포텐셜(potential)
# $ V(r) = - \frac{Z e^2}{4 \pi \epsilon_0 r^2}$

# %% [markdown]
# ![image.png](attachment:image.png)
#
# - 고전역학적으로는 두 물체 간 만유인력의 식과 동일
# - but, 전자는 원자핵 주변을 돌면서 에너지(빛, radiation)을 방출
# - 이대로면 에너지를 잃으면서 전자가 원자핵 쪽으로 추락해야 함

# %% [markdown]
# ![image.png](attachment:image.png)
#
# - 하지만 전자가 원자핵쪽으로 추락하는 경우는 발생하지 않음
# - 전자가 정상파를 만드는 양자화된 조건을 만족하면 원자가 안정적으로 구성됨
# - => 각운동량 양자화
#
# ### 각 운동량 양자화
# - 원자 내부의 전자가 가질수 있는 에너지가 양자화(quantization) 됨
# - 양자화 된 에너지준위 사이에 전이가 발생
# - 전이에 해당하는 에너지를 가진 빛이 방출되거나 흡수

# %% [markdown]
# ## 2. 원자구조2 - 보어모델

# %% [markdown]
# #### 포텐셜(potential) 에너지
# $ V(r) = -k_e \frac{Z e^2}{r^2} = - \frac{Z e^2}{4 \pi \epsilon_0 r^2}$ ($ k_e = \frac{1}{4 \pi \epsilon_0} $)
#
# #### electron volt(eV)
# - 전자 1개가 1V의 전위차에 있을 때 가지는 포텐셜 에너지
# - $ 1eV = 1.6*10^{-19} J$
# - 원자규모에서 일어나는 현상에서 측정되는 에너지 단위

# %%
import numpy as np

# universal constants (상수 설정)
Z = 1 # Hydrogen
e = 1.602e-19 # C
eps0 = 8.854e-12 # in C/ (V m)
m_ang = 1e-10 # meter per angstrom

Joule_eV = e

V = -Z*e**2/(4*np.pi*eps0*1*m_ang)  # in joule
print('수소원자에서 전자가 가지는 포텐셜에너지')
print(V, 'J')
print(V/Joule_eV, 'eV')
# Out:
# 수소원자에서 전자가 가지는 포텐셜에너지
# -2.3066178143822714e-18 J
# -14.398363385657126 eV

# %%
m_e = 9.10938356e-31 # in kg : electron mass 전자의 무게
m_n = 1.6726219e-27 # in kg : proton mass 원자핵의 무게
G = 6.673e-11 # in m^3 kg^-1 s^-2 : Gravitation constant
m_ang = 1e-10 # meter per angstrom

V = -G *m_e*m_n / (1*m_ang)
print('만유인력을 기준으로 했을 때 전자가 가지는 포텐셜 에너지')
print(V, 'J')
print(V/Joule_eV, 'eV')
# Out:
# 만유인력을 기준으로 했을 때 전자가 가지는 포텐셜 에너지
# -1.0167352776448014e-57 J
# -6.34666215758303e-39 eV

# %% [markdown]
# 전자의 쿨롱작용에 의한 포텐셜에너지 >> 만유인력 작용에 의한 포텐셜에너지

# %% [markdown]
# ### 거리에 따른 포텐셜 에너지 그래프 그리기
# #### 1) 전자와 전자
# #### 2) 전자와 양성자
# #### 3) 전자와 세개의 양성자 (Li$^{+2}$)

# %% [markdown]
# ## 3. 선 스펙트럼 계산
